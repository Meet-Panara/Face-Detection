# %%
print("Hello world")
# Out:
# Hello world

# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.array([1,2,4])
y = np.array([2,1,3])

plt.plot(x, y, "o:b")

# %%
pil = Image.open("Dr-Strange.jpg")

# %%
arr = np.array(pil)

# %%
arr.shape
# Out:
# (275, 183, 3)

# %%
pil
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x275>

# %%
cut = arr[:150, 20:170]
plt.imshow(cut)

# %%
red = arr[:, :, 0]
plt.imshow(red)

# %%
copy = arr.copy()
copy[:, :, [1,2]] = 255
plt.imshow(copy)

# %%
gray = arr.mean(axis=2)

# %%
plt.imshow(gray, cmap="gray")
